# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tqdm

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/manavgakhar/CADLab
# Out:
# Cloning into 'CADLab'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 7206 (delta 56), reused 0 (delta 0), pack-reused 7098
# Receiving objects: 100% (7206/7206), 666.70 MiB | 31.08 MiB/s, done.
# Resolving deltas: 100% (2672/2672), done.

# %%
# %cd './CADLab/CXR-Binary-Classifier'
# Out:
# /kaggle/working/CADLab/CXR-Binary-Classifier

# %%
# !python train_densenet.py --arch 'resnet101' --img_size 256 --crop_size 224 --epoch 1 --batch_size 32 --learning_rate 0.001 --gpu 0 --pretrained 'True'
# Out:
# => using pre-trained model 'resnet101'
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100%|█████████████████████████████████████████| 170M/170M [00:01<00:00, 148MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python test_densenet.py --arch 'resnet101' --img_size 256 --crop_size 224 --batch_size 32 --learning_rate 0.001 --gpu 0 --test_labels 'att'
# Out:
# Number of testing CXR images: 1344
# ../../../input/my-nih-data/NIH_data/NIH_images/00011136_001.png: [0.96198076] GT: tensor(1)
# ../../../input/my-nih-data/NIH_data/NIH_images/00030408_011.png: [0.99504155] GT: tensor(1)
# ../../../input/my-nih-data/NIH_data/NIH_images/00030791_000.png: [0.13234445] GT: tensor(0)
# ../../../input/my-nih-data/NIH_data/NIH_images/00017138_021.png: [0.9961682] GT: tensor(1)
# ../../../input/my-nih-data/NIH_data/NIH_images/00015563_013.png: [0.6931206] GT: tensor(0)
# ../../../input/my-nih-data/NIH_data/NIH_images/00026399_001.png: [0.23609483] GT: tensor(0)
# ../../../input/my-nih-data/NIH_data/NIH_images/00029637_000.png: [0.5330383] GT: tensor(0)
# ../../../input/my-nih-data/NIH_data/NIH_images/00029811_000.png: [0.3043452] GT: tensor(0)
# ../../../input/my-nih-data/NIH_data/NIH_images/00011460_046.png: [0.5715576] GT: tensor(1)
# ../../../input/my-nih-data/NIH_data/NIH_images/00030110_000.png: [0.34895945] GT: tensor(0)
# ...
